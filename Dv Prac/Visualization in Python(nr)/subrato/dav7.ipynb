# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sn

# %%
df = pd.read_csv("Real estate.csv")

# %%
df.head()
# Out:
#    No  X1 transaction date  X2 house age
# 0   1             2012.917          32.0  \
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores
# 0                                84.87882                               10  \
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2
# 2     24.98746     121.54391                        47.3
# 3     24.98746     121.54391                        54.8
# 4     24.97937     121.54245                        43.1

# %% [markdown]
# COMPARING CATEGORY

# %%
#HEATMAP
sn.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
#BAR CHARTS
sn.barplot(x = 'X2 house age',y = 'Y house price of unit area',data = df)
plt.show()

# %% [markdown]
# RELATIONSHIP

# %%
#SCATTERPLOT
df.plot(kind='scatter',x='X2 house age',y='Y house price of unit area') # scatter plot
# Out:
# <Axes: xlabel='X2 house age', ylabel='Y house price of unit area'>

# %%
#CORRELATION MATRIX
corr = df.corr()

# %%
sn.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >
