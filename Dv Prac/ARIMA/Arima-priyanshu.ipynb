# %%
pip install statsmodels
# Out:
# Collecting statsmodelsNote: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: C:\Users\heram\AppData\Local\Programs\Python\Python311\python.exe -m pip install --upgrade pip
#   Downloading statsmodels-0.13.5-cp311-cp311-win_amd64.whl (9.0 MB)
#      ---------------------------------------- 9.0/9.0 MB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=0.25 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (2.0.1)
# Collecting patsy>=0.5.2
#   Downloading patsy-0.5.3-py2.py3-none-any.whl (233 kB)
#      -------------------------------------- 233.8/233.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=21.3 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (23.1)
# Requirement already satisfied: scipy>=1.3 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.10.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from statsmodels) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->statsmodels) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->statsmodels) (2023.3)
# Requirement already satisfied: six in c:\users\heram\appdata\local\programs\python\python311\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# Installing collected packages: patsy, statsmodels
# Successfully installed patsy-0.5.3 statsmodels-0.13.5

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('yahoo_stock.csv')
df.head()
# Out:
#          Date         High          Low         Open        Close
# 0  2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  \
# 1  2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893
# 2  2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117
# 3  2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117
# 4  2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107
#
#          Volume    Adj Close
# 0  3.587980e+09  2086.590088
# 1  3.884930e+09  2089.139893
# 2  2.852940e+09  2088.870117
# 3  2.852940e+09  2088.870117
# 4  1.466840e+09  2090.110107

# %%
df['Date']=pd.to_datetime(df['Date'])
df.head()
# Out:
#         Date         High          Low         Open        Close
# 0 2015-11-23  2095.610107  2081.389893  2089.409912  2086.590088  \
# 1 2015-11-24  2094.120117  2070.290039  2084.419922  2089.139893
# 2 2015-11-25  2093.000000  2086.300049  2089.300049  2088.870117
# 3 2015-11-26  2093.000000  2086.300049  2089.300049  2088.870117
# 4 2015-11-27  2093.290039  2084.129883  2088.820068  2090.110107
#
#          Volume    Adj Close
# 0  3.587980e+09  2086.590088
# 1  3.884930e+09  2089.139893
# 2  2.852940e+09  2088.870117
# 3  2.852940e+09  2088.870117
# 4  1.466840e+09  2090.110107

# %%
df.describe()
# Out:
#                       Date         High          Low         Open
# count                 1825  1825.000000  1825.000000  1825.000000  \
# mean   2018-05-23 00:00:00  2660.718673  2632.817580  2647.704751
# min    2015-11-23 00:00:00  1847.000000  1810.099976  1833.400024
# 25%    2017-02-21 00:00:00  2348.350098  2322.250000  2341.979980
# 50%    2018-05-23 00:00:00  2696.250000  2667.840088  2685.489990
# 75%    2019-08-22 00:00:00  2930.790039  2900.709961  2913.860107
# max    2020-11-20 00:00:00  3645.989990  3600.159912  3612.090088
# std                    NaN   409.680853   404.310068   407.169994
#
#              Close        Volume    Adj Close
# count  1825.000000  1.825000e+03  1825.000000
# mean   2647.856284  3.869627e+09  2647.856284
# min    1829.079956  1.296540e+09  1829.079956
# 25%    2328.949951  3.257950e+09  2328.949951
# 50%    2683.340088  3.609740e+09  2683.340088
# 75%    2917.520020  4.142850e+09  2917.520020
# max    3626.909912  9.044690e+09  3626.909912
# std     407.301177  1.087593e+09   407.301177

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1825 non-null   datetime64[ns]
#  1   High       1825 non-null   float64
#  2   Low        1825 non-null   float64
#  3   Open       1825 non-null   float64
#  4   Close      1825 non-null   float64
#  5   Volume     1825 non-null   float64
#  6   Adj Close  1825 non-null   float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 99.9 KB

# %%
sns.heatmap(df.corr());

# %%
df.columns
# Out:
# Index(['Date', 'High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
features=['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close']

# %%
sns.lineplot(x='Date',y='High',data=df)
# Out:
# <Axes: xlabel='Date', ylabel='High'>

# %%
high_dataset=pd.DataFrame(data=df,columns=['High'])

# %%
from statsmodels.tsa.arima.model import ARIMA

# %%
model=ARIMA(high_dataset,order=(4,2,0))
model_fit=model.fit()

# %%
high_dataset.head()
# Out:
#           High
# 0  2095.610107
# 1  2094.120117
# 2  2093.000000
# 3  2093.000000
# 4  2093.290039

# %%
y_pred=model_fit.predict(0,len(high_dataset))
y_pred
# Out:
# 0          0.000000
# 1       3143.420652
# 2       2093.474317
# 3       2092.119783
# 4       2092.408034
#            ...
# 1821    3639.239218
# 1822    3633.267262
# 1823    3624.214459
# 1824    3581.675246
# 1825    3576.855096
# Name: predicted_mean, Length: 1826, dtype: float64

# %%
plt.plot(y_pred)

# %%
df['forecost']=model_fit.predict(start=0,end=len(high_dataset),dynamic=True)
df[['High','forecost']].plot(figsize=(10,7))
# Out:
# <Axes: >
